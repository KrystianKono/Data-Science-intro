# %% [markdown]
# # Data Science Tools and Ecosystems

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Popular languages in Data Science
# * Libraries in Data Science
# * Table for the Tools used in Data Science
# * Arithmetic Expression in python

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1.  Python
# 2.  R
# 3.  Scala
# 4.  Java
# 5.  C

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Matplotlib
# 2. TensorFlow
# 3. Seaborn
# 4. Numpy
# 5. Pandas
# 6. Sci-kit learn

# %% [markdown]
# | Data Science Tools |
# |-------------------|
# | JupyterLabs |
# | PowerBi |
# | Git |

# %% [markdown]
# ### Below are a few examples of evaluating arithemtic expressions in python

# %%
x = (3*4)+5 #This is a simple arithmetic expresstion to multiply then add integers
print(x)
# Out:
# 17

# %%
MIN_PER_HOUR = 60 #Constant
minutes = 200
time_convert = 200/MIN_PER_HOUR #This will convert 200 minutes to hours by diving by 60
print(time_convert)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Krystian
